# %%
# %matplotlib inline
import pandas as pd

# %%
diabetes_df = pd.read_csv('/content/diabetes_clean.csv')

# %% [markdown]
# # Trying a supervised model

# %%
data = diabetes_df.copy()
for i, column in enumerate(list([str(d) for d in data.dtypes])):
    if column == "object":
        data[data.columns[i]] = data[data.columns[i]].fillna(data[data.columns[i]].mode())
        data[data.columns[i]] = data[data.columns[i]].astype("category").cat.codes
    else:
        data[data.columns[i]] = data[data.columns[i]].fillna(data[data.columns[i]].median())

# %%
data.head(5)
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0       0  80.0             0              1                4  25.19
# 1       0  54.0             0              0                0  27.32
# 2       1  28.0             0              0                4  27.32
# 3       0  36.0             0              0                1  23.45
# 4       1  76.0             1              1                1  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
y = data.pop('diabetes')
X = data.copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
clf = RandomForestRegressor(n_estimators=1000, max_depth = 4)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=4, n_estimators=1000)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, clf.predict(X_test))
# Out:
# 0.667570506679762

# %% [markdown]
# # Trying a not supervisated model

# %%
import numpy as np
from scipy.stats import norm

# %%
params = norm.fit(diabetes_df['diabetes'])

# %%
params
# Out:
# (0.085, 0.27888169534768686)

# %%
diabetes_df['prob_total'] = [norm(params[0], params[1]).cdf(x) for x in diabetes_df['diabetes']]

# %%
diabetes_df[diabetes_df['prob_total']>0.95]
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 6      Female  44.0             0              0         0.999483  19.31
# 26       Male  67.0             0              1         0.999483  27.32
# 38       Male  50.0             1              0         0.999483  27.32
# 40       Male  73.0             0              0         0.999483  25.91
# 53     Female  53.0             0              0         0.999483  27.32
# ...       ...   ...           ...            ...              ...    ...
# 99935  Female  65.0             1              1         0.999483  33.55
# 99938    Male  55.0             0              1         0.999483  30.42
# 99957  Female  61.0             0              0         0.999483  34.45
# 99962  Female  58.0             1              0         0.999483  38.31
# 99979  Female  61.0             0              0         0.999483  30.11
#
#        HbA1c_level  blood_glucose_level  diabetes  prob_total
# 6              6.5                  200         1    0.999483
# 26             6.5                  200         1    0.999483
# 38             5.7                  260         1    0.999483
# 40             9.0                  160         1    0.999483
# 53             7.0                  159         1    0.999483
# ...            ...                  ...       ...         ...
# 99935          8.2                  140         1    0.999483
# 99938          6.2                  300         1    0.999483
# 99957          6.5                  280         1    0.999483
# 99962          7.0                  200         1    0.999483
# 99979          6.2                  240         1    0.999483
#
# [8500 rows x 10 columns]

# %%
models_hypertension={}
for hypertension in list(diabetes_df['hypertension'].unique()):
    hypertension_diabetes = diabetes_df[diabetes_df['hypertension'] == hypertension]
    params = norm.fit(hypertension_diabetes['diabetes'])
    models_hypertension[hypertension] = norm(params[0], params[1])

# %%
hypertension_prob = []
for i, row in diabetes_df.iterrows():
    hypertension_prob.append(models_hypertension[row['hypertension']].cdf(row['diabetes']))
diabetes_df['PROB_hypertension'] = hypertension_prob

# %%
diabetes_df[diabetes_df['PROB_hypertension']>0.95]
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 6      Female  44.0             0              0         0.999483  19.31
# 26       Male  67.0             0              1         0.999483  27.32
# 40       Male  73.0             0              0         0.999483  25.91
# 53     Female  53.0             0              0         0.999483  27.32
# 55       Male  50.0             0              0         0.999483  37.16
# ...       ...   ...           ...            ...              ...    ...
# 99919  Female  74.0             0              0         0.999483  29.51
# 99929  Female  37.0             0              0         0.999483  36.87
# 99938    Male  55.0             0              1         0.999483  30.42
# 99957  Female  61.0             0              0         0.999483  34.45
# 99979  Female  61.0             0              0         0.999483  30.11
#
#        HbA1c_level  blood_glucose_level  diabetes  prob_total  \
# 6              6.5                  200         1    0.999483
# 26             6.5                  200         1    0.999483
# 40             9.0                  160         1    0.999483
# 53             7.0                  159         1    0.999483
# 55             9.0                  159         1    0.999483
# ...            ...                  ...       ...         ...
# 99919          8.2                  130         1    0.999483
# 99929          8.8                  160         1    0.999483
# 99938          6.2                  300         1    0.999483
# 99957          6.5                  280         1    0.999483
# 99979          6.2                  240         1    0.999483
#
#        PROB_hypertension
# 6               0.999876
# 26              0.999876
# 40              0.999876
# 53              0.999876
# 55              0.999876
# ...                  ...
# 99919           0.999876
# 99929           0.999876
# 99938           0.999876
# 99957           0.999876
# 99979           0.999876
#
# [6412 rows x 11 columns]
